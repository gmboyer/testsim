# %% [markdown]
# "CORPSE ENZYME Tabletop Roleplaying Game" COMBAT SIMLULATOR
# ---
# Grayson Boyer
#
# Markdown instructions go here.

# %%
from battle_monte_interactive_interface import main
main()
# Out:
# VBox(children=(Tab(children=(VBox(children=(HBox(children=(Text(value='Rhonda', description='Name 1:', placeholder='Type something'), Dropdown(description='Sex:', index=1, options=('male', 'female'), value='female'))), HBox(children=(VBox(children=(IntSlider(value=4, description='STR', max=12, min=4, step=2), IntSlider(value=4, description='DEX', max=12, min=4, step=2), IntSlider(value=4, description='CON', max=12, min=4, step=2), IntSlider(value=4, description='WIS', max=12, min=4, step=2), IntSlider(value=4, description='INT', max=12, min=4, step=2), IntSlider(value=4, description='CHA', max=12, min=4, step=2), IntSlider(value=0, description='LCK', max=4, step=4))), VBox(children=(SelectMultiple(description='Special Abilities', options=('armor training', 'berserk', 'combat dicipline', 'sneak attack'), value=()), Dropdown(description='Fightstyle:', index=5, options=('none', 'well-rounded', 'powerful', 'finesse', 'dual-weapon', 'defensive'), value='defensive'), Dropdown(description='Armor:', index=3, options=('none', 'padded', 'chainmail', 'platemail'), value='platemail'), Checkbox(value=False, description='Dual-Wield?'))))))), VBox(children=(HBox(children=(Text(value='Rufus', description='Name 1:', placeholder='Type something'), Dropdown(description='Sex:', options=('male', 'female'), value='male'))), HBox(children=(VBox(children=(IntSlider(value=4, description='STR', max=12, min=4, step=2), IntSlider(value=4, description='DEX', max=12, min=4, step=2), IntSlider(value=4, description='CON', max=12, min=4, step=2), IntSlider(value=4, description='WIS', max=12, min=4, step=2), IntSlider(value=4, description='INT', max=12, min=4, step=2), IntSlider(value=4, description='CHA', max=12, min=4, step=2), IntSlider(value=0, description='LCK', max=4, step=4))), VBox(children=(SelectMultiple(description='Special Abilities', options=('armor training', 'berserk', 'combat dicipline', 'sneak attack'), value=()), Dropdown(description='Fightstyle:', index=5, options=('none', 'well-rounded', 'powerful', 'finesse', 'dual-weapon', 'defensive'), value='defensive'), Dropdown(description='Armor:', index=3, options=('none', 'padded', 'chainmail', 'platemail'), value='platemail'), Checkbox(value=False, description='Dual-Wield?')))))))), selected_index=1, _titles={'0': 'Combatant 1', '1': 'Combatant 2'}), IntSlider(value=2099, description='# of battles:', max=9999, min=2), IntSlider(value=0, description='Start distance:', max=20), Button(description='Battle!', style=ButtonStyle())))
# Time elapsed:  38.682374238967896  seconds

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Created with Jupyter, delivered by Fastly, rendered by Rackspace.
# </footer>
